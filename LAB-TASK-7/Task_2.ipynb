# %%
import json
data1=[{"month":"Jan" , "sales": 50000},
       {"month":"Feb" , "sales": 55000},
       {"month":"Mar" , "sales": 48000}]
with open("sales.json","w+") as jsonfile1:
    json.dump(data1,jsonfile1)
data2=[{"month":"Jan" , "Expense": 35000},
       {"month":"Feb" , "Expense": 38000},
       {"month":"Mar" , "Expense": 32000}]
with open("Expense.json","w+") as jsonfile2:
    json.dump(data2,jsonfile2)
data3=[{"name":"Alice","department":"Sales","salary":50000},
       {"name":"Bob","department":"Marketing","salary":48000},
       {"name":"Charlie","department":"IT","salary":55000}]
with open("Employee.json","w+") as jsonfile3:
    json.dump(data3,jsonfile3)
with open("sales.json","r+") as js1:
    js1_data=json.load(js1)
print(js1_data)
with open("Expense.json","r+") as js2:
    js1_data2=json.load(js2)
print(js1_data2)
with open("Employee.json","r+") as js3:
    js1_data3=json.load(js3)
print(js1_data3)
total_sales=[]
total_sales1=0
for i in range(len(data1)):
    total_sales.append(js1_data[i]["sales"])
    total_sales1+=total_sales[i]
print(total_sales)
print("Total Sales :",total_sales1)
total_expense=[]
total_expense1=0
for i in range(len(data2)):
    total_expense.append(js1_data2[i]["Expense"])
    total_expense1+=total_expense[i]
print(total_expense)
print("Total expenses :",total_expense1)
Average_salary=[]
Avg_salary=0
Highest_earning_employee=0
for i in range(len(data2)):
    Average_salary.append(js1_data3[i]["salary"])
    Avg_salary+=Average_salary[i]
    Highest_earning_employee=max(Average_salary)
Avg_salary=Avg_salary/len(Average_salary)
print("Average Salary :",Avg_salary)
print("Highest earning employee :",Highest_earning_employee)
Profit_eachMonth=[]
# for i,j in zip(total_sales,total_expense):
#     Profit_eachMonth=total_sales[i]-total_expense[j]
# print(Profit_eachMonth)
Monthly_profit = []
Monthly_Expense=[]
for i in range(len(data1)):
    Monthly_profit.append(total_sales[i])
print(Monthly_profit)
for i in range(len(data2)):
    Monthly_Expense.append(total_expense[i])
print(Monthly_Expense)
# for month
for i in range(len(data1)):
    total_sales.append(js1_data[i]["sales"])
    total_sales1+=total_sales[i]
MAX=[]
for month in range(len(Monthly_profit)):
    sales_amount = Monthly_profit[month]
    expense_amount = Monthly_Expense[month]
    profit = sales_amount - expense_amount
    print(f"Month {month + 1} : profit = {profit}")
    MAX.append(profit)
    # max(MAX)
    
print(f"the month with the maximum profit is : ",max(MAX))
print(f"the month with the minimum profit is : ",min(MAX))
# for sales_record, expense_record in zip(js1_data, js1_data2):
#     month_profit = sales_record["sales"] - expense_record["expenses"]
#     Monthly_profit.append(month_profit)
#     print(f"Profit for month {month_names[count]} : PKR {month_profit}")
#     count+=1
