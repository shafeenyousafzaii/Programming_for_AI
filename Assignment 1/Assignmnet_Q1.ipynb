# %%
import pandas as pd
# import csv as c
Sales_data="/home/shafeen/Documents/My-all-programs--/SEMESTER-3/Programming_for_AI/Assignment 1/datasets/sales_data.csv"
DataFramee=pd.read_csv(Sales_data,encoding='latin-1')
# DataFramee
# total_sales=DataFramee['QUANTITYORDERED']*DataFramee['PRICEEACH']
# print()
# total_sales

# %%
total_sales = DataFramee.groupby('PRODUCTLINE')['SALES'].sum()
total_sales
# Out:
# PRODUCTLINE
# Classic Cars        3919615.66
# Motorcycles         1166388.34
# Planes               975003.57
# Ships                714437.13
# Trains               226243.47
# Trucks and Buses    1127789.84
# Vintage Cars        1903150.84
# Name: SALES, dtype: float64

# %%
DataFramee
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
year_2003_2004_2005_average=DataFramee.groupby('YEAR_ID')['QUANTITYORDERED'].mean()
year_2003_2004_2005_average
# Out:
# YEAR_ID
# 2003    34.612000
# 2004    34.813383
# 2005    36.884937
# Name: QUANTITYORDERED, dtype: float64

# %%
# import matplotlib as mb
# mb.scatter(year_2003_2004_2005_average.index, year_2003_2004_2005_average.values, marker='o')
DataFramee['ORDERDATE'] = pd.to_datetime(DataFramee['ORDERDATE'])
DataFramee['YEAR']=DataFramee['ORDERDATE'].dt.year
year_2003_2004_2005_average_quantity=DataFramee.groupby('YEAR')['QUANTITYORDERED'].mean()
year_2003_2004_2005_average_quantity
# Out:
# YEAR
# 2003    34.612000
# 2004    34.813383
# 2005    36.884937
# Name: QUANTITYORDERED, dtype: float64

# %%
DataFramee
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
import matplotlib.pyplot as mb
# mb.figure(figsize=(8,6))
# mb.scatter(year_2003_2004_2005_average_quantity.index, year_2003_2004_2005_average_quantity.index, marker='o')
# mb.xlabel('YEAR')
# mb.ylabel('QUANTITYORDERED')
# mb.title('Average of Quantaties per Year')
# mb.grid(True)
# # mb.show(year_2003_2004_2005_average_quantity)
# mb.show()
# year_2003_2004_2005_average_quantity.plot()

# %%
mb.figure(figsize=(10, 10))
mb.scatter(year_2003_2004_2005_average_quantity.index, year_2003_2004_2005_average_quantity.values,marker='o')
mb.xlabel('YEAR')
mb.ylabel('AVG QUANTITY')
mb.title('Trend of Average Quantity Sold per Year')
# Out:
# Text(0.5, 1.0, 'Trend of Average Quantity Sold per Year')
